# %% [markdown]
# ## Flight Price:

# %% [markdown]
# Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn  as sns
sns.set_style('darkgrid')
import warnings
warnings.simplefilter('ignore')

# %%
df_flight=pd.read_excel("flight_price.xlsx")

# %%
df_flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df_flight.shape
# Out:
# (10683, 11)

# %%
## No of rows=10683
## no of columns=11

# %% [markdown]
# Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the
# distribution.

# %%
plt.figure(figsize=(10,8))
sns.histplot(df_flight['Price'],kde=True)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %%
sns.kdeplot(df_flight['Price'],shade=True)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Density'>

# %% [markdown]
# Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
df_flight['Price'].min() ## Minimum Price
# Out:
# 1759

# %%
df_flight['Price'].max() ## Maximum Price
# Out:
# 79512

# %%
## Price Ranges between (1759 to 79512)

# %% [markdown]
# Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x=df_flight['Airline'],y=df_flight['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
## From above plot we can see jet airways Business airline has very high price

# %%
## Indigo,spicejet,GoAir and Air Asia Airline has low Prices

# %% [markdown]
# Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
# they may impact your analysis.

# %%
## We can see from above there are lot of outliers

# %%
df_flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
sns.boxplot(df_flight['Price'])
# Out:
# <AxesSubplot: >

# %%
## Outliers has very much impact as this may  lead to misleading of information in model building

# %% [markdown]
# Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
# to identify the peak travel season. What features would you analyze to identify the peak season, and how
# would you present your findings to your boss?

# %%
df_flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df_flight['Date_of_Journey']=pd.to_datetime(df_flight['Date_of_Journey'])

# %%
df_flight.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time                   object
# Arrival_Time               object
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# dtype: object

# %%
df_flight['Day']=df_flight['Date_of_Journey'].dt.day
df_flight['Day']=df_flight['Day'].astype(int)

# %%
df_flight['Month']=df_flight['Date_of_Journey'].dt.month
df_flight['Month']=df_flight['Month'].astype(int)

# %%
df_flight['Year']=df_flight['Date_of_Journey'].dt.year
df_flight['Year']=df_flight['Year'].astype(int)

# %%
df_flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  Day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    5
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    6
# 3    18:05         23:30   5h 25m      1 stop         No info   6218    5
# 4    16:50         21:35   4h 45m      1 stop         No info  13302    3
#
#    Month  Year
# 0      3  2019
# 1      1  2019
# ...

# %%
df_flight['Day'].value_counts()
# Out:
# 6     2166
# 5     1392
# 3     1361
# 27    1130
# 21    1111
# 24    1052
# 15     984
# 18     832
# 4      655
# Name: Day, dtype: int64

# %%
df_flight['Month'].value_counts()
# Out:
# 6     2536
# 3     2211
# 5     2074
# 9     1406
# 1     1075
# 12     957
# 4      424
# Name: Month, dtype: int64

# %%
plt.figure(figsize=(8,8))
df_flight['Month'].value_counts().plot.pie(autopct='%1.1f')
plt.title("Top Seasons for Flight",size=16,color="green")
plt.show()

# %%
## Clearly we can see on the month of June Travels are in Peak (23.7%)and also on 6th Date Travel are more

# %% [markdown]
# Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
# Price dataset to identify any trends in flight prices. What features would you analyze to identify these
# trends, and what visualizations would you use to present your findings to your team?

# %%
## For trend we can use Date of Journey

# %%
df_flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  Day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    5
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    6
# 3    18:05         23:30   5h 25m      1 stop         No info   6218    5
# 4    16:50         21:35   4h 45m      1 stop         No info  13302    3
#
#    Month  Year
# 0      3  2019
# 1      1  2019
# ...

# %%
sns.lineplot(x=df_flight['Date_of_Journey'],y=df_flight['Price'])
# Out:
# <AxesSubplot: xlabel='Date_of_Journey', ylabel='Price'>

# %%
df_airline_sum=df_flight.groupby(["Airline","Date_of_Journey"])['Price'].sum().reset_index()

# %%
df_airline_sum
# Out:
#                      Airline Date_of_Journey   Price
# 0                   Air Asia      2019-01-03   33172
# 1                   Air Asia      2019-01-04   27742
# 2                   Air Asia      2019-01-05   46005
# 3                   Air Asia      2019-01-06   72740
# 4                   Air Asia      2019-03-03   60550
# ..                       ...             ...     ...
# 307                  Vistara      2019-12-05  134591
# 308                  Vistara      2019-12-06  183659
# 309  Vistara Premium economy      2019-01-03    9125
# 310  Vistara Premium economy      2019-03-03   11793
# 311  Vistara Premium economy      2019-06-04    5969
#
# [312 rows x 3 columns]

# %%
df_air_asia=df_airline_sum[df_airline_sum['Airline']=='Air Asia']

# %%
sns.lineplot(x=df_air_asia['Date_of_Journey'],y=df_air_asia['Price'])
# Out:
# <AxesSubplot: xlabel='Date_of_Journey', ylabel='Price'>

# %%
sns.lineplot(x=df_airline_sum['Date_of_Journey'],y=df_airline_sum['Price'])
# Out:
# <AxesSubplot: xlabel='Date_of_Journey', ylabel='Price'>

# %%
## There is seasonality we can see but not able to find any upward or downward trend

# %% [markdown]
# Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
# Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
# identify these factors, and how would you present your findings to the management team?

# %%
## There can be some factors that affect flight prices like  Total_stopm,source Destination as sow below

# %%
df_stop=df_flight.groupby('Total_Stops')['Price'].sum().sort_values(ascending=False)

# %%
sns.barplot(x=df_stop.index,y=df_stop,palette='Set2')
# Out:
# <AxesSubplot: xlabel='Total_Stops', ylabel='Price'>

# %%
df_source=df_flight.groupby('Source')['Price'].sum().sort_values(ascending=False)

# %%
sns.barplot(x=df_source,y=df_source.index,orient='h')
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Source'>

# %%
df_destination=df_flight.groupby('Destination')['Price'].sum().sort_values(ascending=False)

# %%
sns.barplot(x=df_destination,y=df_destination.index,orient='h')
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Destination'>

# %%
df_flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  Day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    5
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    6
# 3    18:05         23:30   5h 25m      1 stop         No info   6218    5
# 4    16:50         21:35   4h 45m      1 stop         No info  13302    3
#
#    Month  Year
# 0      3  2019
# 1      1  2019
# ...

# %%
df_new=df_flight.copy()

# %%
df_new.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  Day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    5
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    6
# 3    18:05         23:30   5h 25m      1 stop         No info   6218    5
# 4    16:50         21:35   4h 45m      1 stop         No info  13302    3
#
#    Month  Year
# 0      3  2019
# 1      1  2019
# ...

# %%
df_new['Duration_Hr']=df_new['Duration'].str.split('h').str[0]

# %%
df_new['Duration_Hr'][(df_new['Duration_Hr']=='5m')]
# Out:
# 6474    5m
# Name: Duration_Hr, dtype: object

# %%
df_new=df_new.drop(index=6474,axis=0)

# %%
df_new.reset_index(drop=True,inplace=True)

# %%
df_new['Duration_Hr']=df_new['Duration_Hr'].astype(int)

# %%
df_new['Duration_Mn']=df_new['Duration'].str.split('h').str[1].str.split('m').str[0]

# %%
df_new['Duration_Mn']=df_new['Duration_Mn'].replace('',0)

# %%
df_new['Duration_Mn']=df_new['Duration_Mn'].astype(int)

# %%
df_new.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  Day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    5
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    6
# 3    18:05         23:30   5h 25m      1 stop         No info   6218    5
# 4    16:50         21:35   4h 45m      1 stop         No info  13302    3
#
#    Month  Year  Duration_Hr  Duration_Mn
# ...

# %%
df_avg_source=df_new.groupby('Source')['Price'].mean()

# %%
sns.barplot(x=df_avg_source.index,y=df_avg_source) ## Delhi As a Source has higher price
# Out:
# <AxesSubplot: xlabel='Source', ylabel='Price'>

# %%
df_avg_Destination=df_new.groupby('Destination')['Price'].mean()

# %%
sns.barplot(x=df_avg_Destination.index,y=df_avg_Destination) ## New delhi as a destination has higher Price
# Out:
# <AxesSubplot: xlabel='Destination', ylabel='Price'>

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=df_new['Duration_Hr'],y=df_new['Price'])
# Out:
# <AxesSubplot: xlabel='Duration_Hr', ylabel='Price'>

# %% [markdown]
# ## Google Playstore:

# %% [markdown]
# Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
# the dataset have?

# %%
df_google=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# %%
df_google.shape
# Out:
# (10841, 13)

# %%
## 10841 rows
## 13 columns

# %% [markdown]
# Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
# app categories.

# %%
df_google.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_google[df_google.duplicated()==True]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df_google.drop_duplicates(inplace=True,keep='first')

# %%
df_google.reset_index(drop=True,inplace=True)

# %%
df_google['Rating'].max()
# Out:
# 19.0

# %%
df_google[(df_google['Rating']>5)]
# Out:
#                                           App Category  Rating Reviews  \
# 9990  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
df_google=df_google[~(df_google['Rating']>5)]  ## Droping Rating value greater than 5

# %%
df_google.reset_index(drop=True,inplace=True)

# %%
df_google[df_google['Rating'].isnull()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10340                            Cardio-FR              MEDICAL     NaN
# 10341                   Naruto & Boruto FR               SOCIAL     NaN
# 10347             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10351                             FR Forms             BUSINESS     NaN
# 10354               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x=df_google['Category'],y=df_google['Rating'])
plt.xticks(rotation=90)
plt.show()

# %%
#df_google.groupby(['Category','App'])['Rating'].mean()

# %% [markdown]
# Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
# impact your analysis.

# %%
df_google.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
## Rating has very high number of missing values 1465
## Type has 1
## Current version has 8
## Android ver has 2 missing vales

# %%
## Since Rating has large numver of missing values it can have very large impact in  recommendation to user 
## while other features with null value can be removed or filled

# %% [markdown]
# Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
# the relationship.

# %%
df_google.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_google['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
df_google['Size']=df_google['Size'].str.replace('M','000')
df_google['Size']=df_google['Size'].str.replace('k','')
df_google['Size']=df_google['Size'].replace('Varies with device',np.nan)
df_google['Size']=df_google['Size'].astype(float)

# %%
df_google.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size     Installs  Type Price Content Rating  \
# 0     159  19000.0      10,000+  Free     0       Everyone
# 1     967  14000.0     500,000+  Free     0       Everyone
# 2   87510      8.7   5,000,000+  Free     0       Everyone
# 3  215644  25000.0  50,000,000+  Free     0           Teen
# 4     967      2.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df_google['Size'],y=df_google['Rating'])
plt.show()

# %%
## From above ,ratings are Hihger mostly but Ratings are much higher for lower size app and dense 
##

# %% [markdown]
# Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
df_g1=df_google.copy()

# %%
#df_google=df_g1.copy()

# %%
df_google.Price.unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df_google['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
chars_to_remove=['+',',','$']
cols_to_clean=['Installs','Price']
for item in chars_to_remove:
    for cols in cols_to_clean:
        df_google[cols]=df_google[cols].str.replace(item,'')

# %%
df_google['Price']=df_google['Price'].astype('float')

# %%
df_google['Installs']=df_google['Installs'].astype('int')

# %%
df_google["Price"].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=df_google['Type'],y=df_google['Price'])
plt.title("Free and Paid Average Price",size=16)
plt.show()

# %% [markdown]
# Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
# with the highest number of installs.

# %%
df_google.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size  Installs  Type  Price Content Rating  \
# 0     159  19000.0     10000  Free    0.0       Everyone
# 1     967  14000.0    500000  Free    0.0       Everyone
# 2   87510      8.7   5000000  Free    0.0       Everyone
# 3  215644  25000.0  50000000  Free    0.0           Teen
# 4     967      2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_google.App.nunique()
# Out:
# 9659

# %%
df_google.shape
# Out:
# (10357, 13)

# %%
df_google.groupby('App')['Installs'].sum().sort_values(ascending=False).head(10).to_frame()
# Out:
#                                 Installs
# App
# Subway Surfers                5000000000
# Google Photos                 4000000000
# Hangouts                      4000000000
# Google News                   3000000000
# Google Chrome: Fast & Secure  3000000000
# Google Drive                  3000000000
# Maps - Navigate & Explore     3000000000
# Instagram                     3000000000
# Candy Crush Saga              2500000000
# Temple Run 2                  2500000000

# %% [markdown]
# Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
# Google Playstore dataset to identify the most popular app categories. How would you approach this
# task, and what features would you analyze to make recommendations to the company?

# %%
df_google.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size  Installs  Type  Price Content Rating  \
# 0     159  19000.0     10000  Free    0.0       Everyone
# 1     967  14000.0    500000  Free    0.0       Everyone
# 2   87510      8.7   5000000  Free    0.0       Everyone
# 3  215644  25000.0  50000000  Free    0.0           Teen
# 4     967      2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_popular_category=df_google['Category'].value_counts().to_frame()

# %%
df_popular_category=df_popular_category.rename(columns={"Category":"Count"})

# %%
## Top 10 Categories

# %%
df_popular_category.head(10)
# Out:
#                  Count
# FAMILY            1943
# GAME              1121
# TOOLS              843
# BUSINESS           427
# MEDICAL            408
# PRODUCTIVITY       407
# PERSONALIZATION    388
# LIFESTYLE          373
# COMMUNICATION      366
# FINANCE            360

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df_popular_category.index[:10], y ='Count',data = df_popular_category[:10],palette='hls')
plt.title('Top 10 App categories',size=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the
# most successful app developers. What features would you analyze to make recommendations to the
# company, and what data visualizations would you use to present your findings?

# %%
df_google.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size  Installs  Type  Price Content Rating  \
# 0     159  19000.0     10000  Free    0.0       Everyone
# 1     967  14000.0    500000  Free    0.0       Everyone
# 2   87510      8.7   5000000  Free    0.0       Everyone
# 3  215644  25000.0  50000000  Free    0.0           Teen
# 4     967      2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_app_devop=df_google.groupby(['App','Rating'])['Installs'].sum().sort_values(ascending=False).to_frame()

# %%
df_app_devop.reset_index(inplace=True)

# %%
df_app_devop.head(10)
# Out:
#                             App  Rating    Installs
# 0                Subway Surfers     4.5  5000000000
# 1                      Hangouts     4.0  4000000000
# 2                 Google Photos     4.5  4000000000
# 3     Maps - Navigate & Explore     4.3  3000000000
# 4                   Google News     3.9  3000000000
# 5                     Instagram     4.5  3000000000
# 6                  Google Drive     4.4  3000000000
# 7  Google Chrome: Fast & Secure     4.3  3000000000
# 8              Candy Crush Saga     4.4  2500000000
# 9                  Temple Run 2     4.3  2500000000

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=df_app_devop['App'][:5],y=df_app_devop['Installs'][:5],palette='Set2')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to
# launch a new app. What features would you analyze to make recommendations to the company, and
# what data visualizations would you use to present your findings?

# %%
df_google.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size  Installs  Type  Price Content Rating  \
# 0     159  19000.0     10000  Free    0.0       Everyone
# 1     967  14000.0    500000  Free    0.0       Everyone
# 2   87510      8.7   5000000  Free    0.0       Everyone
# 3  215644  25000.0  50000000  Free    0.0           Teen
# 4     967      2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_google.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size              float64
# Installs            int64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df_google['Last Updated']=pd.to_datetime(df_google['Last Updated'])

# %%
df_google.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews     Size  Installs  Type  Price Content Rating  \
# 0     159  19000.0     10000  Free    0.0       Everyone
# 1     967  14000.0    500000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver
# 0               Art & Design   2018-01-07       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0  4.0.3 and up

# %%
df_google['Day']=df_google['Last Updated'].dt.day

# %%
df_google['Month']=df_google['Last Updated'].dt.month

# %%
df_google.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews     Size  Installs  Type  Price Content Rating  \
# 0     159  19000.0     10000  Free    0.0       Everyone
# 1     967  14000.0    500000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver  Day  \
# 0               Art & Design   2018-01-07       1.0.0  4.0.3 and up    7
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0  4.0.3 and up   15
#
#    Month
# 0      1
# 1      1

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df_google['Day'])
plt.title("Day wise Updation",size=16,color='blue')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df_google['Month'])
plt.title("Month wise Updation",size=16,color='green')
plt.show()

# %%
## From above we can clearly see there is large spike in month of July (7th Month) ,  and during the first 3 days of the  month we can lanch our app
